# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
read_file=pd.read_csv('car.csv')
read_file.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
read_file.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ## Select features

# %%
X = read_file['enginesize'].values
y = read_file['price'].values

# %%
X = X.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2 ,random_state=100)

# %%
x_train.shape # 80% of X data
# Out:
# (164, 1)

# %%
x_test.shape # 20% of X data
# Out:
# (41, 1)

# %%
plt.scatter(x_train, y_train, color='blue')
plt.xlabel('engine size')
plt.ylabel('price')
plt.title('Training Data')
plt.show()

# %% [markdown]
# ## create the model and train it

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## testing

# %%
y_predict = model.predict(x_test)

# %%
y_test
# Out:
# array([ 7738.,  8495.,  8845.,  9298.,  7603., 11245., 18420., 16503.,
#        17669., 17199., 16845., 18150., 15580., 12945., 40960.,  6855.,
#         6938., 12170., 18280., 14869., 13415., 16515., 32528.,  5572.,
#         8449., 13499., 12764., 28176., 16925., 11048.,  6189., 30760.,
#        13860., 19045., 16630., 10698., 15040.,  9989.,  6849.,  8948.,
#        45400.])

# %%
y_predict
# Out:
# array([ 8443.95536325, 10293.86530664, 12480.12251248,  8443.95536325,
#        10125.69167543, 12480.12251248, 13825.51156222, 15507.2478744 ,
#        16516.28966171, 22402.36675434, 15675.42150562, 12311.94888126,
#        12143.77525004, 10462.03893786, 43760.41791901,  7434.91357594,
#         8443.95536325, 12311.94888126, 15507.2478744 , 18198.02597389,
#        15675.42150562, 15675.42150562, 24588.62396017,  7098.5663135 ,
#        16516.28966171, 22402.36675434, 18198.02597389, 22738.71401677,
#        10125.69167543, 11975.60161882,  7434.91357594, 27111.22842844,
#        17525.33144902, 15675.42150562, 12143.77525004, 10462.03893786,
#        12311.94888126, 16516.28966171,  8275.78173203, 12480.12251248,
#        43087.72339414])

# %%
new_engine_size = np.array([120]).reshape(-1,1)
new_engine_size
# Out:
# array([[120]])

# %%
model.predict(new_engine_size)
# Out:
# array([12143.77525004])

# %%
new_engine_size = np.array([140]).reshape(-1,1)

# %%
model.predict(new_engine_size)
# Out:
# array([15507.2478744])

# %% [markdown]
# ## Accuracy of model

# %%
model.score(x_train, y_train)*100
# Out:
# 74.47887279553049

# %%
model.score(x_test, y_test)*100
# Out:
# 80.68161903454086

# %% [markdown]
# ### Plotting the predicted output vs. the test output

# %%
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_test, y_predict, color='red')
plt.xlabel('engine size')
plt.ylabel('price')
plt.title('Training Data vs Model')
plt.show()

# %% [markdown]
# ## Repeat the process for horsepower feature

# %%
salary = pd.read_csv('car.csv')
salary.head()
X = salary['horsepower'].values
y = salary['price'].values
X = X.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2 ,random_state=100)

# %%
y_train
# Out:
# array([13950.   ,  7198.   ,  8499.   ,  5399.   ,  8949.   ,  7609.   ,
#         9279.   ,  7995.   ,  9495.   ,  6795.   ,  9639.   ,  8238.   ,
#         9995.   , 18920.   ,  7898.   ,  8921.   ,  8921.   , 12964.   ,
#         7775.   , 10295.   , 37028.   ,  7609.   , 22018.   ,  9538.   ,
#        16500.   , 18950.   ,  9980.   ,  7499.   , 11248.   , 15750.   ,
#         7999.   ,  6229.   , 18150.   , 13645.   ,  8916.5  ,  6918.   ,
#         6989.   , 34028.   ,  6338.   , 22625.   , 16430.   ,  6575.   ,
#        11199.   , 12629.   , 20970.   , 41315.   , 16558.   ,  7099.   ,
#         5499.   ,  8916.5  ,  8358.   , 17950.   , 11595.   , 13845.   ,
#         8013.   ,  6095.   ,  9988.   ,  8845.   ,  8058.   ,  7895.   ,
#        17710.   ,  7395.   ,  6692.   ,  5572.   , 35550.   , 17859.167,
#         7957.   ,  7295.   , 16900.   ,  5195.   , 10245.   , 11259.   ,
#         7463.   ,  6295.   , 12940.   , 10945.   ,  7775.   ,  6377.   ,
# ...

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([ 7831.01527804, 10212.79010542, 10054.00511693, 14499.98479471,
#         8307.37024351, 10054.00511693, 22439.23421932, 24503.43906971,
#        15135.12474868, 22121.66424233, 14817.55477169, 22121.66424233,
#        11800.63999034, 12753.34992129, 25932.50396614,  8783.72520899,
#         7831.01527804, 14182.41481772, 15770.26470264, 19739.88941495,
#        14817.55477169, 14817.55477169, 29584.55870146,  7513.44530105,
#        15135.12474868, 20851.38433439, 19739.88941495, 16246.61966812,
#        12753.34992129, 11006.71504788,  7513.44530105, 25614.93398916,
#        11800.63999034, 22121.66424233, 12118.20996732,  8307.37024351,
#        14182.41481772, 15135.12474868,  7672.23028954, 11324.28502486,
#        25932.50396614])

# %%
y_test
# Out:
# array([ 7738.,  8495.,  8845.,  9298.,  7603., 11245., 18420., 16503.,
#        17669., 17199., 16845., 18150., 15580., 12945., 40960.,  6855.,
#         6938., 12170., 18280., 14869., 13415., 16515., 32528.,  5572.,
#         8449., 13499., 12764., 28176., 16925., 11048.,  6189., 30760.,
#        13860., 19045., 16630., 10698., 15040.,  9989.,  6849.,  8948.,
#        45400.])

# %%
model.score(x_train, y_train)*100
# Out:
# 66.03310279425133

# %%
model.score(x_test, y_test)*100
# Out:
# 60.495543109700776

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_test, y_predict, color='yellow')
plt.xlabel('horse power')
plt.ylabel('price')
plt.title('Training Data vs Model')
plt.show()

# %% [markdown]
# ## Repeat the process for wheelbase feature

# %%
read_file_1 = pd.read_csv('car.csv')
read_file_1.head()
X = read_file_1['wheelbase'].values
y = read_file_1['price'].values
X = X.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2 ,random_state=100)

# %%
y_train
# Out:
# array([13950.   ,  7198.   ,  8499.   ,  5399.   ,  8949.   ,  7609.   ,
#         9279.   ,  7995.   ,  9495.   ,  6795.   ,  9639.   ,  8238.   ,
#         9995.   , 18920.   ,  7898.   ,  8921.   ,  8921.   , 12964.   ,
#         7775.   , 10295.   , 37028.   ,  7609.   , 22018.   ,  9538.   ,
#        16500.   , 18950.   ,  9980.   ,  7499.   , 11248.   , 15750.   ,
#         7999.   ,  6229.   , 18150.   , 13645.   ,  8916.5  ,  6918.   ,
#         6989.   , 34028.   ,  6338.   , 22625.   , 16430.   ,  6575.   ,
#        11199.   , 12629.   , 20970.   , 41315.   , 16558.   ,  7099.   ,
#         5499.   ,  8916.5  ,  8358.   , 17950.   , 11595.   , 13845.   ,
#         8013.   ,  6095.   ,  9988.   ,  8845.   ,  8058.   ,  7895.   ,
#        17710.   ,  7395.   ,  6692.   ,  5572.   , 35550.   , 17859.167,
#         7957.   ,  7295.   , 16900.   ,  5195.   , 10245.   , 11259.   ,
#         7463.   ,  6295.   , 12940.   , 10945.   ,  7775.   ,  6377.   ,
# ...

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([10750.25745252, 11971.93819264, 13117.26388651,  9833.99689743,
#         8917.73634234, 13117.26388651, 17316.79143067, 16095.11069055,
#        12811.84370148,  7390.63541719, 20981.83365103, 13346.32902528,
#        20065.57309594, 11361.09782258, 29991.72910942,  3801.94824309,
#        10750.25745252, 13346.32902528, 17774.92170821, 10902.96754504,
#        17316.79143067, 17316.79143067,  6016.24458456,  9223.15652737,
#        12811.84370148, 14338.94462663, 10902.96754504, 19149.31254085,
#        14949.78499669, 10979.3225913 ,  9223.15652737, 16705.95106061,
#        24875.94101016, 20981.83365103, 20065.57309594, 15866.04555178,
#        13346.32902528, 12811.84370148,  9833.99689743, 15866.04555178,
#        23196.1299925 ])

# %%
plt.scatter(x_train, y_train, color='green')
plt.plot(x_test, y_predict, color='yellow')
plt.xlabel('wheelbase')
plt.ylabel('price')
plt.title('Training Data vs Model')
plt.show()

# %% [markdown]
# ### Seaborn Library

# %%
import seaborn as sns

# %% [markdown]
# #### Using seaborn to plot

# %%
sns.set()
# _ = plt.plot([0, 1], color="g")
plt.figure(figsize=(20,20),dpi=300)
sns.regplot(x='wheelbase', color="g", y='price', data=read_file)
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='price'>

# %%
read_file.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...
